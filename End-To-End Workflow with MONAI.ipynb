# %% [markdown]
# <a href="https://colab.research.google.com/github/colleenrpy/MONAI_handson/blob/main/End-To-End%20Workflow%20with%20MONAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://github.com/Project-MONAI/MONAIBootcamp2021/blob/main/day1/monai.png?raw=1" style="width: 700px;"/>
#
# Welcome to the MONAI bootcamp! This notebook will introduce you to an end-to-end workin in MONAI using both a standard PyTorch loop and using Ignite, followed by a hands-on implementing your own segmentation using everything you've learned so far.

# %% [markdown]
# ### Using Google Colab
#
# This notebook has the pip command for installing MONAI and will be added to any subsequent notebook.
#
# **Required Packages for Colab Execution**
#
# Execute the following cell to install MONAI the first time a colab notebook is run:

# %%
# !pip install -qU "monai[ignite, nibabel, torchvision, tqdm]==0.6.0"
# Out:
#      |████████████████████████████████| 584 kB 2.1 MB/s
#      |████████████████████████████████| 221 kB 68.7 MB/s

# %% [markdown]
# **Enabling GPU Support**
#
# To use GPU resources through Colab, change the runtime to GPU:
#
# 1. From the **"Runtime"** menu select **"Change Runtime Type"**
# 2. Choose **"GPU"** from the drop-down menu
# 3. Click **"SAVE"**
#
# This will reset the notebook and probably ask you if you are a robot (these instructions assume you are not). Running
#
# **!nvidia-smi**
#
# in a cell will verify this has worked and show you what kind of hardware you have access to.

# %%
# !nvidia-smi
# Out:
# Fri Sep 30 01:55:33 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # End-to-end Training with Pytorch and Ignite
# ---

# %% [markdown]
# We've covered a lot of material and now it's time to apply the things that we've learned in an end-to-end example.  First, we're going to use the basic PyTorch paradigm for training our model.  We'll then look at how to train using the Ignite workflows to make things even easier!
#
#
# ## End-to-End Training Workflow
#
# To help guide you through training your first model using MONAI, this guide will will cover five key phases:
#
# 1. **Setting up our Dataset and exploring the data**
# 2. **Preparing datasets and transforms**
# 3. **Define your network and create our PyTorch training loop**
# 4. **Evaluate your model and understand the results**
# 5. **Start using Ignite and more about determinism**

# %% [markdown]
# Let's get started by importing our dependencies.

# %%
import os
import shutil
import tempfile

import matplotlib.pyplot as plt
import numpy as np
import PIL

import torch
import monai

from monai.apps import download_and_extract
from monai.config import print_config
from monai.metrics import ROCAUCMetric
from monai.data import decollate_batch, partition_dataset_classes
from monai.networks.nets import DenseNet121
from monai.transforms import (
    AddChannel,
    Compose,
    LoadImage,
    RandFlip,
    RandRotate,
    RandZoom,
    ScaleIntensity,
    ToTensor,
    Activations,
    AsDiscrete,
    EnsureType
)
from monai.utils import set_determinism

# %% [markdown]
# ## **1. Setting up our Dataset and exploring the data**

# %% [markdown]
# #### Setup data directory
#
# We'll create a temporary directory for all the MONAI data we're going to be using called MONAI_DATA_DIRECTORY.

# %%
directory = os.environ.get("MONAI_DATA_DIRECTORY")
root_dir = tempfile.mkdtemp() if directory is None else directory
print(root_dir)
# Out:
# /tmp/tmpwpz203rq

# %% [markdown]
# #### Download the MedNIST dataset
# The `MedNIST` dataset was gathered from several sets from [TCIA](https://wiki.cancerimagingarchive.net/display/Public/Data+Usage+Policies+and+Restrictions),
# [the RSNA Bone Age Challenge](http://rsnachallenges.cloudapp.net/competitions/4),
# and [the NIH Chest X-ray dataset](https://cloud.google.com/healthcare/docs/resources/public-datasets/nih-chest).
#
# The dataset is kindly made available by [Dr. Bradley J. Erickson M.D., Ph.D.](https://www.mayo.edu/research/labs/radiology-informatics/overview) (Department of Radiology, Mayo Clinic)
# under the Creative Commons [CC BY-SA 4.0 license](https://creativecommons.org/licenses/by-sa/4.0/). If you use the MedNIST dataset, please acknowledge the source.
#
# We're going to download this dataset below and extract it into our temporary MONAI Data Directory.

# %%
resource = "https://www.dropbox.com/s/5wwskxctvcxiuea/MedNIST.tar.gz?dl=1"
md5 = "0bc7306e7427e00ad1c5526a6677552d"

compressed_file = os.path.join(root_dir, "MedNIST.tar.gz")
data_dir = os.path.join(root_dir, "MedNIST")
if not os.path.exists(data_dir):
    download_and_extract(resource, compressed_file, root_dir, md5)
# Out:
# MedNIST.tar.gz: 59.0MB [00:07, 8.03MB/s]
# Downloaded: /tmp/tmpwpz203rq/MedNIST.tar.gz
# Verified 'MedNIST.tar.gz', md5: 0bc7306e7427e00ad1c5526a6677552d.
# Writing into directory: /tmp/tmpwpz203rq.

# %% [markdown]
# #### Set deterministic training for reproducibility
# [set_determinism](https://docs.monai.io/en/latest/utils.html?highlight=set_determinism#monai.utils.misc.set_determinism) will set the random seeds in both Numpy and PyTorch to ensure reproducibility. We'll see later that we need to go a little bit further to ensure reproducibility in a jupyter notebook

# %%
set_determinism(seed=0)

# %% [markdown]
# #### Read the image filenames from the dataset folders
#
# When using a dataset, you want to understand the basics of the images, labels, and more.  We'll start off by showing some of those basic statistics for MedNIST.
#
# We'll see that 6 different folders are representing 6 different categories: Hand, AbdomenCT, CXR, ChestCT, BreastMRI, HeadCT.  We'll be using each of these categories as our label names.

# %%
class_names = sorted(x for x in os.listdir(data_dir) if os.path.isdir(os.path.join(data_dir, x)))
num_class = len(class_names)

image_files = [
    [
        os.path.join(data_dir, class_names[i], x)
        for x in os.listdir(os.path.join(data_dir, class_names[i]))
    ]
    for i in range(num_class)
]

num_each = [len(image_files[i]) for i in range(num_class)]
image_files_list = []
image_class = []

for i in range(num_class):
    image_files_list.extend(image_files[i])
    image_class.extend([i] * num_each[i])
    
num_total = len(image_class)
image_width, image_height = PIL.Image.open(image_files_list[0]).size

print(f"Total image count: {num_total}")
print(f"Image dimensions: {image_width} x {image_height}")
print(f"Label names: {class_names}")
print(f"Label counts: {num_each}")
# Out:
# Total image count: 58954
# Image dimensions: 64 x 64
# Label names: ['AbdomenCT', 'BreastMRI', 'CXR', 'ChestCT', 'Hand', 'HeadCT']
# Label counts: [10000, 8954, 10000, 10000, 10000, 10000]

# %% [markdown]
# #### Randomly pick images from the dataset to visualize and check
#
# We want to understand what the images we're using look like, so we'll start by visualizing a few random images.

# %%
plt.subplots(3, 3, figsize=(8, 8))
for i, k in enumerate(np.random.randint(num_total, size=9)):
    im = PIL.Image.open(image_files_list[k])
    arr = np.array(im)
    plt.subplot(3, 3, i + 1)
    plt.xlabel(class_names[image_class[k]])
    plt.imshow(arr, cmap="gray", vmin=0, vmax=255)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **2. Preparing datasets and transforms**

# %% [markdown]
# #### Prepare training, validation, and test data lists
#
# We want to split the data into 3 different sets, one for training, one for validation, and one for testing.  We'll use a ratio of 80/10/10 for those sets.

# %%
train_inds, val_inds, test_inds = partition_dataset_classes(np.arange(len(image_files_list)), 
                                                            image_class,(8, 1, 1), shuffle=True)

train_x = [image_files_list[i] for i in train_inds]
train_y = [image_class[i] for i in train_inds]
val_x = [image_files_list[i] for i in val_inds]
val_y = [image_class[i] for i in val_inds]
test_x = [image_files_list[i] for i in test_inds]
test_y = [image_class[i] for i in test_inds]

print(f"Training count: {len(train_x)}, Validation count: {len(val_x)}, Test count: {len(test_x)}")
# Out:
# Training count: 47163, Validation count: 5895, Test count: 5895

# %% [markdown]
# #### Define MONAI transforms, Dataset and Dataloader to pre-process data
#
# We'll define our transform using `Compose`.  In this Array of Transforms, we'll load the image, add a channel, scale its intensity, utilize a few random functions and finally create a tensor.

# %%
train_transforms = Compose(
    [
        LoadImage(image_only=True),
        AddChannel(),
        ScaleIntensity(),
        RandRotate(range_x=15, prob=0.5, keep_size=True),
        RandFlip(spatial_axis=0, prob=0.5),
        RandZoom(min_zoom=0.9, max_zoom=1.1, prob=0.5),
        ToTensor(),
    ]
)

val_transforms = Compose([LoadImage(image_only=True), AddChannel(), ScaleIntensity(), ToTensor()])

act = Compose([EnsureType(), Activations(softmax=True)])
to_onehot = Compose([EnsureType(), AsDiscrete(to_onehot=True, n_classes=num_class)])

# %% [markdown]
# #### Initialise the datasets and loaders for training, validation and test sets
#  * Define a simple dataset, that we'll call `MedNISTDataset`, that groups:
#    * Images
#    * Labels
#    * The transforms that are to be run on the images and labels
#  * Create three instances of this dataset:
#    * One for training
#    * One for validation
#    * One for testing
#
# We'll use a batch size of 512 and employ 10 workers to load the data.

# %%
batch_size = 512
num_workers = 10

class MedNISTDataset(torch.utils.data.Dataset):
    def __init__(self, image_files, labels, transforms):
        self.image_files = image_files
        self.labels = labels
        self.transforms = transforms

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, index):
        return self.transforms(self.image_files[index]), self.labels[index]


train_ds = MedNISTDataset(train_x, train_y, train_transforms)
train_loader = torch.utils.data.DataLoader(train_ds, batch_size=batch_size, shuffle=True, num_workers=num_workers)

val_ds = MedNISTDataset(val_x, val_y, val_transforms)
val_loader = torch.utils.data.DataLoader(val_ds, batch_size=batch_size, num_workers=num_workers)

test_ds = MedNISTDataset(test_x, test_y, val_transforms)
test_loader = torch.utils.data.DataLoader(test_ds, batch_size=batch_size, num_workers=num_workers)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 10 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %% [markdown]
# ## **3. Define your network and create our PyTorch training loop**

# %% [markdown]
# #### Define network and optimizer
#
# 1. Set `learning_rate` for how much the model is updated per step
# 1. The fetch a pytorch `device` for the GPU
# 1. Instantiate a [densenet121](https://docs.monai.io/en/latest/networks.html?highlight=densenet#monai.networks.nets.densenet121) model instance and 'send' it to the GPU using `device`
#   * This is a standard MONAI implementation; it is capable of 2D and 3D operation but here we are using it in 2D mode
# 1. We'll make use of the Adam optimizer

# %%
learning_rate = 1e-5
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
net = DenseNet121(spatial_dims=2, in_channels=1, out_channels=num_class).to(device)
loss_function = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(net.parameters(), learning_rate)

# %% [markdown]
# #### Network training
# We are hand-rolling a basic pytorch training loop here:
#  * standard pytorch training loop
#    * step through each training epoch, running through the training set in batches
#    * after each epoch, run a validation pass, evaluating the network
#    * if it shows improved performance, save out the model weights
#  * later we will revisit training loops in a more Ignite / MONAI fashion

# %%
epoch_num = 4
best_metric = -1
best_metric_epoch = -1
epoch_loss_values = list()
metric_values = list()
auc_metric = ROCAUCMetric()

for epoch in range(epoch_num):
    print("-" * 10)
    print(f"epoch {epoch + 1}/{epoch_num}")

    epoch_loss = 0
    step = 1

    steps_per_epoch = len(train_ds) // train_loader.batch_size

    # put the network in train mode; this tells the network and its modules to
    # enable training elements such as normalisation and dropout, where applicable
    net.train()
    for batch_data in train_loader:

        # move the data to the GPU
        inputs, labels = batch_data[0].to(device), batch_data[1].to(device)

        # prepare the gradients for this step's back propagation
        optimizer.zero_grad()
        
        # run the network forwards
        outputs = net(inputs)
        
        # run the loss function on the outputs
        loss = loss_function(outputs, labels)
        
        # compute the gradients
        loss.backward()
        
        # tell the optimizer to update the weights according to the gradients
        # and its internal optimisation strategy
        optimizer.step()

        epoch_loss += loss.item()
        print(f"{step}/{len(train_ds) // train_loader.batch_size + 1}, training_loss: {loss.item():.4f}")
        step += 1

    epoch_loss /= step
    epoch_loss_values.append(epoch_loss)
    print(f"epoch {epoch + 1} average loss: {epoch_loss:.4f}")

    # after each epoch, run our metrics to evaluate it, and, if they are an improvement,
    # save the model out
    
    # switch off training features of the network for this pass
    net.eval()

    # 'with torch.no_grad()' switches off gradient calculation for the scope of its context
    with torch.no_grad():
        # create lists to which we will concatenate the the validation results
        preds = list()
        labels = list()

        # iterate over each batch of images and run them through the network in evaluation mode
        for val_data in val_loader:
            val_images, val_labels = val_data[0].to(device), val_data[1].to(device)

            # run the network
            val_pred = net(val_images)

            preds.append(val_pred)
            labels.append(val_labels)

        # concatenate the predicted labels with each other and the actual labels with each other
        y_pred = torch.cat(preds)
        y = torch.cat(labels)

        # we are using the area under the receiver operating characteristic (ROC) curve to determine
        # whether this epoch has improved the best performance of the network so far, in which case
        # we save the network in this state
        y_onehot = [to_onehot(i) for i in decollate_batch(y)]        
        y_pred_act = [act(i) for i in decollate_batch(y_pred)]
        
        auc_metric(y_pred_act, y_onehot)
        auc_value = auc_metric.aggregate()
        auc_metric.reset()
        metric_values.append(auc_value)
        
        acc_value = torch.eq(y_pred.argmax(dim=1), y)
        acc_metric = acc_value.sum().item() / len(acc_value)
        
        if auc_value > best_metric:
            best_metric = auc_value
            best_metric_epoch = epoch + 1
            torch.save(net.state_dict(), os.path.join(root_dir, "best_metric_model.pth"))
            print("saved new best metric network")
            
        print(
            f"current epoch: {epoch + 1} current AUC: {auc_value:.4f} /"
            f" current accuracy: {acc_metric:.4f} best AUC: {best_metric:.4f} /"
            f" at epoch: {best_metric_epoch}"
        )

print(f"train completed, best_metric: {best_metric:.4f} at epoch: {best_metric_epoch}")
# Out:
# ----------
# epoch 1/4
# 1/93, training_loss: 1.7875
# 2/93, training_loss: 1.7646
# 3/93, training_loss: 1.7332
# 4/93, training_loss: 1.7127
# 5/93, training_loss: 1.6808
# 6/93, training_loss: 1.6698
# 7/93, training_loss: 1.6645
# 8/93, training_loss: 1.6277
# 9/93, training_loss: 1.5970
# 10/93, training_loss: 1.5936
# 11/93, training_loss: 1.5510
# 12/93, training_loss: 1.5360
# 13/93, training_loss: 1.5206
# 14/93, training_loss: 1.5038
# 15/93, training_loss: 1.4582
# 16/93, training_loss: 1.4510
# 17/93, training_loss: 1.4497
# 18/93, training_loss: 1.4393
# 19/93, training_loss: 1.3770
# 20/93, training_loss: 1.3806
# 21/93, training_loss: 1.3519
# 22/93, training_loss: 1.3513
# 23/93, training_loss: 1.3414
# 24/93, training_loss: 1.3124
# 25/93, training_loss: 1.2960
# 26/93, training_loss: 1.2578
# 27/93, training_loss: 1.2742
# 28/93, training_loss: 1.2356
# 29/93, training_loss: 1.2246
# 30/93, training_loss: 1.2047
# 31/93, training_loss: 1.2006
# 32/93, training_loss: 1.2137
# 33/93, training_loss: 1.1984
# 34/93, training_loss: 1.1675
# 35/93, training_loss: 1.1313
# 36/93, training_loss: 1.1478
# 37/93, training_loss: 1.1170
# 38/93, training_loss: 1.1212
# 39/93, training_loss: 1.1210
# 40/93, training_loss: 1.0664
# 41/93, training_loss: 1.0375
# 42/93, training_loss: 1.0526
# 43/93, training_loss: 1.0392
# 44/93, training_loss: 1.0207
# 45/93, training_loss: 1.0144
# 46/93, training_loss: 1.0188
# 47/93, training_loss: 0.9899
# 48/93, training_loss: 0.9659
# 49/93, training_loss: 0.9715
# 50/93, training_loss: 0.9289
# 51/93, training_loss: 0.9505
# 52/93, training_loss: 0.9141
# 53/93, training_loss: 0.9243
# 54/93, training_loss: 0.8829
# 55/93, training_loss: 0.9114
# 56/93, training_loss: 0.8980
# 57/93, training_loss: 0.8902
# 58/93, training_loss: 0.8571
# 59/93, training_loss: 0.8399
# 60/93, training_loss: 0.8787
# 61/93, training_loss: 0.8623
# 62/93, training_loss: 0.8424
# 63/93, training_loss: 0.8002
# 64/93, training_loss: 0.8038
# 65/93, training_loss: 0.7882
# 66/93, training_loss: 0.7708
# 67/93, training_loss: 0.7889
# 68/93, training_loss: 0.7890
# 69/93, training_loss: 0.7286
# 70/93, training_loss: 0.7601
# 71/93, training_loss: 0.7508
# 72/93, training_loss: 0.7339
# 73/93, training_loss: 0.7239
# 74/93, training_loss: 0.6983
# 75/93, training_loss: 0.6795
# 76/93, training_loss: 0.6929
# 77/93, training_loss: 0.6937
# 78/93, training_loss: 0.6609
# 79/93, training_loss: 0.6742
# 80/93, training_loss: 0.6193
# 81/93, training_loss: 0.6851
# 82/93, training_loss: 0.7041
# 83/93, training_loss: 0.6445
# 84/93, training_loss: 0.6536
# 85/93, training_loss: 0.6317
# 86/93, training_loss: 0.6144
# 87/93, training_loss: 0.5986
# 88/93, training_loss: 0.5681
# 89/93, training_loss: 0.5686
# 90/93, training_loss: 0.5563
# 91/93, training_loss: 0.5974
# 92/93, training_loss: 0.5775
# 93/93, training_loss: 0.5494
# epoch 1 average loss: 1.0386
# saved new best metric network
# current epoch: 1 current AUC: 0.9927 / current accuracy: 0.9332 best AUC: 0.9927 / at epoch: 1
# ----------
# epoch 2/4
# 1/93, training_loss: 0.5407
# 2/93, training_loss: 0.5461
# 3/93, training_loss: 0.5825
# 4/93, training_loss: 0.5760
# 5/93, training_loss: 0.5096
# 6/93, training_loss: 0.5580
# 7/93, training_loss: 0.5180
# 8/93, training_loss: 0.5162
# 9/93, training_loss: 0.5496
# 10/93, training_loss: 0.4981
# 11/93, training_loss: 0.5030
# 12/93, training_loss: 0.4970
# 13/93, training_loss: 0.5248
# 14/93, training_loss: 0.4670
# 15/93, training_loss: 0.4671
# 16/93, training_loss: 0.4757
# 17/93, training_loss: 0.4961
# 18/93, training_loss: 0.4606
# 19/93, training_loss: 0.4983
# 20/93, training_loss: 0.4335
# 21/93, training_loss: 0.4335
# 22/93, training_loss: 0.4407
# 23/93, training_loss: 0.4287
# 24/93, training_loss: 0.4406
# 25/93, training_loss: 0.4154
# 26/93, training_loss: 0.4418
# 27/93, training_loss: 0.4046
# 28/93, training_loss: 0.4232
# 29/93, training_loss: 0.4145
# 30/93, training_loss: 0.3931
# 31/93, training_loss: 0.4039
# 32/93, training_loss: 0.3872
# 33/93, training_loss: 0.3961
# 34/93, training_loss: 0.3692
# 35/93, training_loss: 0.3840
# 36/93, training_loss: 0.4164
# 37/93, training_loss: 0.3964
# 38/93, training_loss: 0.3901
# 39/93, training_loss: 0.3732
# 40/93, training_loss: 0.3630
# 41/93, training_loss: 0.3871
# 42/93, training_loss: 0.3512
# 43/93, training_loss: 0.3887
# 44/93, training_loss: 0.3352
# 45/93, training_loss: 0.3396
# 46/93, training_loss: 0.3282
# 47/93, training_loss: 0.3695
# 48/93, training_loss: 0.2994
# 49/93, training_loss: 0.3358
# 50/93, training_loss: 0.3419
# 51/93, training_loss: 0.3583
# 52/93, training_loss: 0.3117
# 53/93, training_loss: 0.3276
# 54/93, training_loss: 0.3295
# 55/93, training_loss: 0.3237
# 56/93, training_loss: 0.3043
# 57/93, training_loss: 0.2982
# 58/93, training_loss: 0.3156
# 59/93, training_loss: 0.3237
# 60/93, training_loss: 0.3351
# 61/93, training_loss: 0.2814
# 62/93, training_loss: 0.2993
# 63/93, training_loss: 0.2991
# 64/93, training_loss: 0.2742
# 65/93, training_loss: 0.3116
# 66/93, training_loss: 0.2871
# 67/93, training_loss: 0.2928
# 68/93, training_loss: 0.2727
# 69/93, training_loss: 0.2449
# 70/93, training_loss: 0.2847
# 71/93, training_loss: 0.2773
# 72/93, training_loss: 0.2815
# 73/93, training_loss: 0.2751
# 74/93, training_loss: 0.2792
# 75/93, training_loss: 0.2372
# 76/93, training_loss: 0.2888
# 77/93, training_loss: 0.2509
# 78/93, training_loss: 0.2513
# 79/93, training_loss: 0.2485
# 80/93, training_loss: 0.2485
# 81/93, training_loss: 0.2271
# 82/93, training_loss: 0.2349
# 83/93, training_loss: 0.2355
# 84/93, training_loss: 0.2626
# 85/93, training_loss: 0.2568
# 86/93, training_loss: 0.2332
# 87/93, training_loss: 0.2390
# 88/93, training_loss: 0.2396
# 89/93, training_loss: 0.2320
# 90/93, training_loss: 0.2145
# 91/93, training_loss: 0.2350
# 92/93, training_loss: 0.2330
# 93/93, training_loss: 0.2512
# epoch 2 average loss: 0.3576
# saved new best metric network
# current epoch: 2 current AUC: 0.9986 / current accuracy: 0.9645 best AUC: 0.9986 / at epoch: 2
# ----------
# epoch 3/4
# 1/93, training_loss: 0.2154
# 2/93, training_loss: 0.2198
# 3/93, training_loss: 0.2529
# 4/93, training_loss: 0.2149
# 5/93, training_loss: 0.2410
# 6/93, training_loss: 0.2336
# 7/93, training_loss: 0.2017
# 8/93, training_loss: 0.2124
# 9/93, training_loss: 0.2109
# 10/93, training_loss: 0.2251
# 11/93, training_loss: 0.2163
# 12/93, training_loss: 0.2062
# 13/93, training_loss: 0.1911
# 14/93, training_loss: 0.2206
# 15/93, training_loss: 0.1967
# 16/93, training_loss: 0.1657
# 17/93, training_loss: 0.1957
# 18/93, training_loss: 0.2187
# 19/93, training_loss: 0.1889
# 20/93, training_loss: 0.2023
# 21/93, training_loss: 0.1938
# 22/93, training_loss: 0.2069
# 23/93, training_loss: 0.1843
# 24/93, training_loss: 0.1983
# 25/93, training_loss: 0.1975
# 26/93, training_loss: 0.1651
# 27/93, training_loss: 0.1802
# 28/93, training_loss: 0.2081
# 29/93, training_loss: 0.2070
# 30/93, training_loss: 0.1954
# 31/93, training_loss: 0.1802
# 32/93, training_loss: 0.1579
# 33/93, training_loss: 0.2040
# 34/93, training_loss: 0.1747
# 35/93, training_loss: 0.1888
# 36/93, training_loss: 0.1763
# 37/93, training_loss: 0.1812
# 38/93, training_loss: 0.1706
# 39/93, training_loss: 0.1755
# 40/93, training_loss: 0.1760
# 41/93, training_loss: 0.1703
# 42/93, training_loss: 0.1681
# 43/93, training_loss: 0.1609
# 44/93, training_loss: 0.1646
# 45/93, training_loss: 0.1726
# 46/93, training_loss: 0.1495
# 47/93, training_loss: 0.1828
# 48/93, training_loss: 0.1778
# 49/93, training_loss: 0.1708
# 50/93, training_loss: 0.1498
# 51/93, training_loss: 0.1532
# 52/93, training_loss: 0.1754
# 53/93, training_loss: 0.1720
# 54/93, training_loss: 0.1612
# 55/93, training_loss: 0.1576
# 56/93, training_loss: 0.1640
# 57/93, training_loss: 0.1657
# 58/93, training_loss: 0.1641
# 59/93, training_loss: 0.1503
# 60/93, training_loss: 0.1560
# 61/93, training_loss: 0.1845
# 62/93, training_loss: 0.1629
# 63/93, training_loss: 0.1228
# 64/93, training_loss: 0.1320
# 65/93, training_loss: 0.1564
# 66/93, training_loss: 0.1453
# 67/93, training_loss: 0.1464
# 68/93, training_loss: 0.1265
# 69/93, training_loss: 0.1381
# 70/93, training_loss: 0.1333
# 71/93, training_loss: 0.1463
# 72/93, training_loss: 0.1378
# 73/93, training_loss: 0.1320
# 74/93, training_loss: 0.1188
# 75/93, training_loss: 0.1307
# 76/93, training_loss: 0.1577
# 77/93, training_loss: 0.1257
# 78/93, training_loss: 0.1348
# 79/93, training_loss: 0.1299
# 80/93, training_loss: 0.1380
# 81/93, training_loss: 0.1152
# 82/93, training_loss: 0.1422
# 83/93, training_loss: 0.1422
# 84/93, training_loss: 0.1458
# 85/93, training_loss: 0.1273
# 86/93, training_loss: 0.1404
# 87/93, training_loss: 0.1249
# 88/93, training_loss: 0.1533
# 89/93, training_loss: 0.1365
# 90/93, training_loss: 0.1320
# 91/93, training_loss: 0.1163
# 92/93, training_loss: 0.1219
# 93/93, training_loss: 0.1056
# epoch 3 average loss: 0.1675
# saved new best metric network
# current epoch: 3 current AUC: 0.9995 / current accuracy: 0.9818 best AUC: 0.9995 / at epoch: 3
# ----------
# epoch 4/4
# 1/93, training_loss: 0.1203
# 2/93, training_loss: 0.1385
# 3/93, training_loss: 0.1394
# 4/93, training_loss: 0.1309
# 5/93, training_loss: 0.1180
# 6/93, training_loss: 0.1306
# 7/93, training_loss: 0.1245
# 8/93, training_loss: 0.1257
# 9/93, training_loss: 0.1477
# 10/93, training_loss: 0.1182
# 11/93, training_loss: 0.1187
# 12/93, training_loss: 0.1101
# 13/93, training_loss: 0.1062
# 14/93, training_loss: 0.1070
# 15/93, training_loss: 0.1117
# 16/93, training_loss: 0.1108
# 17/93, training_loss: 0.1015
# 18/93, training_loss: 0.1115
# 19/93, training_loss: 0.1366
# 20/93, training_loss: 0.1221
# 21/93, training_loss: 0.1289
# 22/93, training_loss: 0.1003
# 23/93, training_loss: 0.0996
# 24/93, training_loss: 0.1050
# 25/93, training_loss: 0.1141
# 26/93, training_loss: 0.1118
# 27/93, training_loss: 0.1254
# 28/93, training_loss: 0.1025
# 29/93, training_loss: 0.1153
# 30/93, training_loss: 0.1176
# 31/93, training_loss: 0.1153
# 32/93, training_loss: 0.1172
# 33/93, training_loss: 0.1407
# 34/93, training_loss: 0.1207
# 35/93, training_loss: 0.1128
# 36/93, training_loss: 0.1125
# 37/93, training_loss: 0.1366
# 38/93, training_loss: 0.1007
# 39/93, training_loss: 0.1008
# 40/93, training_loss: 0.1100
# 41/93, training_loss: 0.1235
# 42/93, training_loss: 0.1037
# 43/93, training_loss: 0.1053
# 44/93, training_loss: 0.1089
# 45/93, training_loss: 0.1068
# 46/93, training_loss: 0.1111
# 47/93, training_loss: 0.1109
# 48/93, training_loss: 0.0919
# 49/93, training_loss: 0.0875
# 50/93, training_loss: 0.0998
# 51/93, training_loss: 0.1108
# 52/93, training_loss: 0.1050
# 53/93, training_loss: 0.0992
# 54/93, training_loss: 0.1023
# 55/93, training_loss: 0.1013
# 56/93, training_loss: 0.1250
# 57/93, training_loss: 0.1173
# 58/93, training_loss: 0.1000
# 59/93, training_loss: 0.0812
# 60/93, training_loss: 0.1007
# 61/93, training_loss: 0.1155
# 62/93, training_loss: 0.0862
# 63/93, training_loss: 0.0962
# 64/93, training_loss: 0.0987
# 65/93, training_loss: 0.0915
# 66/93, training_loss: 0.0834
# 67/93, training_loss: 0.1139
# 68/93, training_loss: 0.1163
# 69/93, training_loss: 0.1027
# 70/93, training_loss: 0.1234
# 71/93, training_loss: 0.1091
# 72/93, training_loss: 0.0914
# 73/93, training_loss: 0.0829
# 74/93, training_loss: 0.0727
# 75/93, training_loss: 0.0763
# 76/93, training_loss: 0.1090
# 77/93, training_loss: 0.1032
# 78/93, training_loss: 0.0758
# 79/93, training_loss: 0.1160
# 80/93, training_loss: 0.0743
# 81/93, training_loss: 0.0987
# 82/93, training_loss: 0.0895
# 83/93, training_loss: 0.0940
# 84/93, training_loss: 0.0870
# 85/93, training_loss: 0.0979
# 86/93, training_loss: 0.1139
# 87/93, training_loss: 0.0886
# 88/93, training_loss: 0.0923
# 89/93, training_loss: 0.1004
# 90/93, training_loss: 0.0927
# 91/93, training_loss: 0.1109
# 92/93, training_loss: 0.0917
# 93/93, training_loss: 0.1105
# epoch 4 average loss: 0.1066
# saved new best metric network
# current epoch: 4 current AUC: 0.9998 / current accuracy: 0.9873 best AUC: 0.9998 / at epoch: 4
# train completed, best_metric: 0.9998 at epoch: 4

# %% [markdown]
# #### Plot the loss and metric
#
# Once we're done training we want to visualize our Loss and Accuracy.

# %%
plt.figure("train", (12, 6))
plt.subplot(1, 2, 1)
plt.title("Epoch Average Loss")
x = [i + 1 for i in range(len(epoch_loss_values))]
y = epoch_loss_values
plt.xlabel("epoch")
plt.plot(x, y)
plt.subplot(1, 2, 2)
plt.title("Val AUC")
x = [(i + 1) for i in range(len(metric_values))]
y = metric_values
plt.xlabel("epoch")
plt.plot(x, y)
plt.show()

# %% [markdown]
# ## **4. Evaluate your model and understand the results**

# %% [markdown]
# #### Evaluate the model on the test dataset
#
# After training and validation, we now have the best model as determined by the validation dataset.  But now we need to evaluate the model on the test dataset to check whether the final model is robust and not over-fitting.  We'll use these predictions to generate a classification report.

# %%
net.load_state_dict(torch.load(os.path.join(root_dir, "best_metric_model.pth")))
net.eval()
y_true = list()
y_pred = list()

with torch.no_grad():
    for test_data in test_loader:
        test_images, test_labels = (
            test_data[0].to(device),
            test_data[1].to(device),
        )
        pred = net(test_images).argmax(dim=1)
        
        for i in range(len(pred)):
            y_true.append(test_labels[i].item())
            y_pred.append(pred[i].item())

# %% [markdown]
# #### Some light analytics - classification report
#
# We'll utilize scikit-learn's classification report to get the precision, recall, and f1-score for each category.

# %%
from sklearn.metrics import classification_report
print(classification_report(y_true, y_pred, target_names=class_names, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#    AbdomenCT     0.9858    0.9710    0.9783      1000
#    BreastMRI     0.9944    0.9933    0.9939       895
#          CXR     0.9960    0.9850    0.9904      1000
#      ChestCT     0.9921    1.0000    0.9960      1000
#         Hand     0.9861    0.9900    0.9880      1000
#       HeadCT     0.9764    0.9910    0.9836      1000
#
#     accuracy                         0.9883      5895
#    macro avg     0.9884    0.9884    0.9884      5895
# weighted avg     0.9883    0.9883    0.9883      5895

# %% [markdown]
# #### Some light analytics - confusion matrix
#
# Let's also create a confusion matrix to get a better understanding of the failure cases

# %%
from sklearn.metrics import confusion_matrix
cmat = confusion_matrix(y_true, y_pred)
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(confusion_matrix(y_true, y_pred), cmap="terrain", interpolation='nearest')
fig.colorbar(cax)

ax.set_xticklabels(['']+class_names, rotation=270)
ax.set_yticklabels(['']+class_names)

plt.show()

# %% [markdown]
# ## **5. Start using Ignite and more about determinism**

# %% [markdown]
# #### Let's make some changes
# Everything that we have done so far uses MONAI with pytorch in a very vanilla fashion. The initial training / validation loop is written to show you the nuts and bolts of pytorch. Now let's explore starting the move towards [Ignite](https://pytorch.org/ignite/) and features of MONAI designed to work with it.
#
# <img src="https://github.com/Project-MONAI/MONAIBootcamp2021/blob/main/day1/workflows.png?raw=1" style="width: 700px;"/>

# %%
from ignite.engine import Events, create_supervised_evaluator, create_supervised_trainer
from ignite.handlers import ModelCheckpoint
from ignite.metrics import Accuracy
from monai.handlers import ROCAUC

step = 1
iter_losses=[]
batch_sizes=[]
epoch_loss_values = []
metric_values = []

# Training

# this trainer takes care of the training loop for us
trainer = create_supervised_trainer(net, optimizer, loss_function, device, False)

# calculate the number of steps per epoch up front
steps_per_epoch = len(train_ds) // train_loader.batch_size
if len(train_ds) % train_loader.batch_size != 0:
    steps_per_epoch += 1


# create a handler for recording the loss after each input. Improve upon our earlier example
# by also recording the batch size, so we can perform a weighted average for the overall average
# loss
@trainer.on(Events.ITERATION_COMPLETED)
def _end_iter(engine):
    global step
    loss = engine.state.output
    batch_len = len(engine.state.batch[0])
    epoch = engine.state.epoch
    epoch_len = engine.state.max_epochs
    iter_losses.append(loss)
    batch_sizes.append(batch_len)
    print(f'epoch {epoch}/{epoch_len}, step {step}/{steps_per_epoch}, training_loss = {loss:.4f}')    
    step += 1
    
# Validation

def roc_auc_trans(x):
    return [act(i) for i in decollate_batch(x[0])], [to_onehot(i) for i in decollate_batch(x[1])]

val_metrics = {
    'accuracy': Accuracy(), 
    'rocauc': ROCAUC(output_transform=roc_auc_trans)
}
evaluator = create_supervised_evaluator(
    net,
    val_metrics,
    device,
    True
)


# validation is run every n training epochs in response to the trainer completing
# an epoch. Here we use the decorator syntax to add a function that runs it to the
# EPOCH_COMPLETED event
@trainer.on(Events.EPOCH_COMPLETED)
def run_validation(engine):
    global step
    evaluator.run(val_loader)

    # the overall average loss must be weighted by batch size
    overall_average_loss = np.average(iter_losses, weights=batch_sizes)
    epoch_loss_values.append(overall_average_loss)

    # clear the contents of iter_losses and batch_sizes for the next epoch
    del iter_losses[:]
    del batch_sizes[:]
    
    # fetch and report the validation metrics
    acc = evaluator.state.metrics['accuracy']
    roc = evaluator.state.metrics['rocauc']
    metric_values.append(roc)
    print(f"evaluation for epoch {engine.state.epoch}, accuracy = {acc:.4f}, rocauc = {roc:.4f}")

    # reset step for the next epoch
    step = 1
    
# create a checkpoint handler to save the network weights based on the area under the ROC curve
# as before
def _score(_):
    return metric_values[-1]

# create a model checkpointer to save the network
checkpoint_handler = ModelCheckpoint(root_dir, filename_prefix='best_metric_model', score_name='',
                                     n_saved=1, require_empty=False, score_function=_score)

# handlers are attached to events in trainers and evaluators
trainer.add_event_handler(event_name=Events.EPOCH_COMPLETED,
                          handler=checkpoint_handler, to_save={'net': net})

# train (and evaluate) the network, Ignite-style!
train_epochs = 4
state = trainer.run(train_loader, train_epochs)

best_rocauc = max(metric_values)
print(f"train completed, best_metric: {best_rocauc:.4f} at epoch: {metric_values.index(best_rocauc)}")
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 10 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# epoch 1/4, step 1/93, training_loss = 0.0851
# epoch 1/4, step 2/93, training_loss = 0.0787
# epoch 1/4, step 3/93, training_loss = 0.0830
# epoch 1/4, step 4/93, training_loss = 0.0752
# epoch 1/4, step 5/93, training_loss = 0.1024
# epoch 1/4, step 6/93, training_loss = 0.0830
# epoch 1/4, step 7/93, training_loss = 0.1211
# epoch 1/4, step 8/93, training_loss = 0.1024
# epoch 1/4, step 9/93, training_loss = 0.0770
# epoch 1/4, step 10/93, training_loss = 0.0876
# epoch 1/4, step 11/93, training_loss = 0.0880
# epoch 1/4, step 12/93, training_loss = 0.0930
# epoch 1/4, step 13/93, training_loss = 0.0849
# epoch 1/4, step 14/93, training_loss = 0.0910
# epoch 1/4, step 15/93, training_loss = 0.0931
# epoch 1/4, step 16/93, training_loss = 0.0914
# epoch 1/4, step 17/93, training_loss = 0.0848
# epoch 1/4, step 18/93, training_loss = 0.0902
# epoch 1/4, step 19/93, training_loss = 0.1100
# epoch 1/4, step 20/93, training_loss = 0.0878
# epoch 1/4, step 21/93, training_loss = 0.0738
# epoch 1/4, step 22/93, training_loss = 0.0660
# epoch 1/4, step 23/93, training_loss = 0.0882
# epoch 1/4, step 24/93, training_loss = 0.0679
# epoch 1/4, step 25/93, training_loss = 0.0979
# epoch 1/4, step 26/93, training_loss = 0.0838
# epoch 1/4, step 27/93, training_loss = 0.0914
# epoch 1/4, step 28/93, training_loss = 0.0801
# epoch 1/4, step 29/93, training_loss = 0.0726
# epoch 1/4, step 30/93, training_loss = 0.0719
# epoch 1/4, step 31/93, training_loss = 0.0726
# epoch 1/4, step 32/93, training_loss = 0.0801
# epoch 1/4, step 33/93, training_loss = 0.0648
# epoch 1/4, step 34/93, training_loss = 0.0834
# epoch 1/4, step 35/93, training_loss = 0.0662
# epoch 1/4, step 36/93, training_loss = 0.0730
# epoch 1/4, step 37/93, training_loss = 0.0613
# epoch 1/4, step 38/93, training_loss = 0.0514
# epoch 1/4, step 39/93, training_loss = 0.1032
# epoch 1/4, step 40/93, training_loss = 0.0674
# epoch 1/4, step 41/93, training_loss = 0.0771
# epoch 1/4, step 42/93, training_loss = 0.0695
# epoch 1/4, step 43/93, training_loss = 0.0816
# epoch 1/4, step 44/93, training_loss = 0.0688
# epoch 1/4, step 45/93, training_loss = 0.0829
# epoch 1/4, step 46/93, training_loss = 0.0749
# epoch 1/4, step 47/93, training_loss = 0.0683
# epoch 1/4, step 48/93, training_loss = 0.0660
# epoch 1/4, step 49/93, training_loss = 0.0835
# epoch 1/4, step 50/93, training_loss = 0.0788
# epoch 1/4, step 51/93, training_loss = 0.0764
# epoch 1/4, step 52/93, training_loss = 0.0747
# epoch 1/4, step 53/93, training_loss = 0.0892
# epoch 1/4, step 54/93, training_loss = 0.0691
# epoch 1/4, step 55/93, training_loss = 0.0612
# epoch 1/4, step 56/93, training_loss = 0.0685
# epoch 1/4, step 57/93, training_loss = 0.0719
# epoch 1/4, step 58/93, training_loss = 0.0751
# epoch 1/4, step 59/93, training_loss = 0.0700
# epoch 1/4, step 60/93, training_loss = 0.0662
# epoch 1/4, step 61/93, training_loss = 0.0866
# epoch 1/4, step 62/93, training_loss = 0.0832
# epoch 1/4, step 63/93, training_loss = 0.0656
# epoch 1/4, step 64/93, training_loss = 0.0743
# epoch 1/4, step 65/93, training_loss = 0.0853
# epoch 1/4, step 66/93, training_loss = 0.0778
# epoch 1/4, step 67/93, training_loss = 0.0582
# epoch 1/4, step 68/93, training_loss = 0.0816
# epoch 1/4, step 69/93, training_loss = 0.0658
# epoch 1/4, step 70/93, training_loss = 0.0582
# epoch 1/4, step 71/93, training_loss = 0.0666
# epoch 1/4, step 72/93, training_loss = 0.0607
# epoch 1/4, step 73/93, training_loss = 0.0629
# epoch 1/4, step 74/93, training_loss = 0.0830
# epoch 1/4, step 75/93, training_loss = 0.0715
# epoch 1/4, step 76/93, training_loss = 0.0703
# epoch 1/4, step 77/93, training_loss = 0.0506
# epoch 1/4, step 78/93, training_loss = 0.0829
# epoch 1/4, step 79/93, training_loss = 0.0486
# epoch 1/4, step 80/93, training_loss = 0.0799
# epoch 1/4, step 81/93, training_loss = 0.0562
# epoch 1/4, step 82/93, training_loss = 0.0665
# epoch 1/4, step 83/93, training_loss = 0.0500
# epoch 1/4, step 84/93, training_loss = 0.0759
# epoch 1/4, step 85/93, training_loss = 0.0685
# epoch 1/4, step 86/93, training_loss = 0.0576
# epoch 1/4, step 87/93, training_loss = 0.0622
# epoch 1/4, step 88/93, training_loss = 0.0685
# epoch 1/4, step 89/93, training_loss = 0.0548
# epoch 1/4, step 90/93, training_loss = 0.0618
# epoch 1/4, step 91/93, training_loss = 0.0797
# epoch 1/4, step 92/93, training_loss = 0.0708
# epoch 1/4, step 93/93, training_loss = 0.0637
# evaluation for epoch 1, accuracy = 0.9907, rocauc = 0.9999
# epoch 2/4, step 1/93, training_loss = 0.0601
# epoch 2/4, step 2/93, training_loss = 0.0687
# epoch 2/4, step 3/93, training_loss = 0.0834
# epoch 2/4, step 4/93, training_loss = 0.0741
# epoch 2/4, step 5/93, training_loss = 0.0642
# epoch 2/4, step 6/93, training_loss = 0.0741
# epoch 2/4, step 7/93, training_loss = 0.0649
# epoch 2/4, step 8/93, training_loss = 0.0497
# epoch 2/4, step 9/93, training_loss = 0.0775
# epoch 2/4, step 10/93, training_loss = 0.0799
# epoch 2/4, step 11/93, training_loss = 0.0698
# epoch 2/4, step 12/93, training_loss = 0.0610
# epoch 2/4, step 13/93, training_loss = 0.0585
# epoch 2/4, step 14/93, training_loss = 0.0588
# epoch 2/4, step 15/93, training_loss = 0.0731
# epoch 2/4, step 16/93, training_loss = 0.0789
# epoch 2/4, step 17/93, training_loss = 0.0878
# epoch 2/4, step 18/93, training_loss = 0.0636
# epoch 2/4, step 19/93, training_loss = 0.0847
# epoch 2/4, step 20/93, training_loss = 0.0492
# epoch 2/4, step 21/93, training_loss = 0.0639
# epoch 2/4, step 22/93, training_loss = 0.0679
# epoch 2/4, step 23/93, training_loss = 0.0723
# epoch 2/4, step 24/93, training_loss = 0.0778
# epoch 2/4, step 25/93, training_loss = 0.0693
# epoch 2/4, step 26/93, training_loss = 0.0537
# epoch 2/4, step 27/93, training_loss = 0.0594
# epoch 2/4, step 28/93, training_loss = 0.0486
# epoch 2/4, step 29/93, training_loss = 0.0525
# epoch 2/4, step 30/93, training_loss = 0.0608
# epoch 2/4, step 31/93, training_loss = 0.0736
# epoch 2/4, step 32/93, training_loss = 0.0604
# epoch 2/4, step 33/93, training_loss = 0.0561
# epoch 2/4, step 34/93, training_loss = 0.0515
# epoch 2/4, step 35/93, training_loss = 0.0539
# epoch 2/4, step 36/93, training_loss = 0.0740
# epoch 2/4, step 37/93, training_loss = 0.0655
# epoch 2/4, step 38/93, training_loss = 0.0601
# epoch 2/4, step 39/93, training_loss = 0.0536
# epoch 2/4, step 40/93, training_loss = 0.0499
# epoch 2/4, step 41/93, training_loss = 0.0564
# epoch 2/4, step 42/93, training_loss = 0.0576
# epoch 2/4, step 43/93, training_loss = 0.0506
# epoch 2/4, step 44/93, training_loss = 0.0458
# epoch 2/4, step 45/93, training_loss = 0.0427
# epoch 2/4, step 46/93, training_loss = 0.0565
# epoch 2/4, step 47/93, training_loss = 0.0437
# epoch 2/4, step 48/93, training_loss = 0.0586
# epoch 2/4, step 49/93, training_loss = 0.0578
# epoch 2/4, step 50/93, training_loss = 0.0641
# epoch 2/4, step 51/93, training_loss = 0.0545
# epoch 2/4, step 52/93, training_loss = 0.0476
# epoch 2/4, step 53/93, training_loss = 0.0362
# epoch 2/4, step 54/93, training_loss = 0.0598
# epoch 2/4, step 55/93, training_loss = 0.0396
# epoch 2/4, step 56/93, training_loss = 0.0408
# epoch 2/4, step 57/93, training_loss = 0.0417
# epoch 2/4, step 58/93, training_loss = 0.0664
# epoch 2/4, step 59/93, training_loss = 0.0530
# epoch 2/4, step 60/93, training_loss = 0.0500
# epoch 2/4, step 61/93, training_loss = 0.0379
# epoch 2/4, step 62/93, training_loss = 0.0608
# epoch 2/4, step 63/93, training_loss = 0.0606
# epoch 2/4, step 64/93, training_loss = 0.0509
# epoch 2/4, step 65/93, training_loss = 0.0523
# epoch 2/4, step 66/93, training_loss = 0.0543
# epoch 2/4, step 67/93, training_loss = 0.0479
# epoch 2/4, step 68/93, training_loss = 0.0617
# epoch 2/4, step 69/93, training_loss = 0.0638
# epoch 2/4, step 70/93, training_loss = 0.0554
# epoch 2/4, step 71/93, training_loss = 0.0450
# epoch 2/4, step 72/93, training_loss = 0.0509
# epoch 2/4, step 73/93, training_loss = 0.0526
# epoch 2/4, step 74/93, training_loss = 0.0450
# epoch 2/4, step 75/93, training_loss = 0.0577
# epoch 2/4, step 76/93, training_loss = 0.0600
# epoch 2/4, step 77/93, training_loss = 0.0542
# epoch 2/4, step 78/93, training_loss = 0.0480
# epoch 2/4, step 79/93, training_loss = 0.0472
# epoch 2/4, step 80/93, training_loss = 0.0476
# epoch 2/4, step 81/93, training_loss = 0.0511
# epoch 2/4, step 82/93, training_loss = 0.0655
# epoch 2/4, step 83/93, training_loss = 0.0553
# epoch 2/4, step 84/93, training_loss = 0.0523
# epoch 2/4, step 85/93, training_loss = 0.0514
# epoch 2/4, step 86/93, training_loss = 0.0535
# epoch 2/4, step 87/93, training_loss = 0.0581
# epoch 2/4, step 88/93, training_loss = 0.0504
# epoch 2/4, step 89/93, training_loss = 0.0448
# epoch 2/4, step 90/93, training_loss = 0.0532
# epoch 2/4, step 91/93, training_loss = 0.0557
# epoch 2/4, step 92/93, training_loss = 0.0455
# epoch 2/4, step 93/93, training_loss = 0.0356
# evaluation for epoch 2, accuracy = 0.9956, rocauc = 1.0000
# epoch 3/4, step 1/93, training_loss = 0.0653
# epoch 3/4, step 2/93, training_loss = 0.0647
# epoch 3/4, step 3/93, training_loss = 0.0634
# epoch 3/4, step 4/93, training_loss = 0.0750
# epoch 3/4, step 5/93, training_loss = 0.0387
# epoch 3/4, step 6/93, training_loss = 0.0420
# epoch 3/4, step 7/93, training_loss = 0.0423
# epoch 3/4, step 8/93, training_loss = 0.0474
# epoch 3/4, step 9/93, training_loss = 0.0363
# epoch 3/4, step 10/93, training_loss = 0.0607
# epoch 3/4, step 11/93, training_loss = 0.0486
# epoch 3/4, step 12/93, training_loss = 0.0722
# epoch 3/4, step 13/93, training_loss = 0.0591
# epoch 3/4, step 14/93, training_loss = 0.0439
# epoch 3/4, step 15/93, training_loss = 0.0379
# epoch 3/4, step 16/93, training_loss = 0.0534
# epoch 3/4, step 17/93, training_loss = 0.0469
# epoch 3/4, step 18/93, training_loss = 0.0452
# epoch 3/4, step 19/93, training_loss = 0.0358
# epoch 3/4, step 20/93, training_loss = 0.0413
# epoch 3/4, step 21/93, training_loss = 0.0581
# epoch 3/4, step 22/93, training_loss = 0.0467
# epoch 3/4, step 23/93, training_loss = 0.0398
# epoch 3/4, step 24/93, training_loss = 0.0426
# epoch 3/4, step 25/93, training_loss = 0.0523
# epoch 3/4, step 26/93, training_loss = 0.0623
# epoch 3/4, step 27/93, training_loss = 0.0600
# epoch 3/4, step 28/93, training_loss = 0.0609
# epoch 3/4, step 29/93, training_loss = 0.0404
# epoch 3/4, step 30/93, training_loss = 0.0372
# epoch 3/4, step 31/93, training_loss = 0.0513
# epoch 3/4, step 32/93, training_loss = 0.0495
# epoch 3/4, step 33/93, training_loss = 0.0379
# epoch 3/4, step 34/93, training_loss = 0.0305
# epoch 3/4, step 35/93, training_loss = 0.0574
# epoch 3/4, step 36/93, training_loss = 0.0421
# epoch 3/4, step 37/93, training_loss = 0.0340
# epoch 3/4, step 38/93, training_loss = 0.0467
# epoch 3/4, step 39/93, training_loss = 0.0330
# epoch 3/4, step 40/93, training_loss = 0.0384
# epoch 3/4, step 41/93, training_loss = 0.0474
# epoch 3/4, step 42/93, training_loss = 0.0322
# epoch 3/4, step 43/93, training_loss = 0.0559
# epoch 3/4, step 44/93, training_loss = 0.0297
# epoch 3/4, step 45/93, training_loss = 0.0509
# epoch 3/4, step 46/93, training_loss = 0.0625
# epoch 3/4, step 47/93, training_loss = 0.0441
# epoch 3/4, step 48/93, training_loss = 0.0374
# epoch 3/4, step 49/93, training_loss = 0.0400
# epoch 3/4, step 50/93, training_loss = 0.0379
# epoch 3/4, step 51/93, training_loss = 0.0578
# epoch 3/4, step 52/93, training_loss = 0.0421
# epoch 3/4, step 53/93, training_loss = 0.0263
# epoch 3/4, step 54/93, training_loss = 0.0631
# epoch 3/4, step 55/93, training_loss = 0.0409
# epoch 3/4, step 56/93, training_loss = 0.0450
# epoch 3/4, step 57/93, training_loss = 0.0369
# epoch 3/4, step 58/93, training_loss = 0.0309
# epoch 3/4, step 59/93, training_loss = 0.0494
# epoch 3/4, step 60/93, training_loss = 0.0452
# epoch 3/4, step 61/93, training_loss = 0.0429
# epoch 3/4, step 62/93, training_loss = 0.0387
# epoch 3/4, step 63/93, training_loss = 0.0580
# epoch 3/4, step 64/93, training_loss = 0.0431
# epoch 3/4, step 65/93, training_loss = 0.0336
# epoch 3/4, step 66/93, training_loss = 0.0359
# epoch 3/4, step 67/93, training_loss = 0.0349
# epoch 3/4, step 68/93, training_loss = 0.0679
# epoch 3/4, step 69/93, training_loss = 0.0415
# epoch 3/4, step 70/93, training_loss = 0.0418
# epoch 3/4, step 71/93, training_loss = 0.0489
# epoch 3/4, step 72/93, training_loss = 0.0571
# epoch 3/4, step 73/93, training_loss = 0.0494
# epoch 3/4, step 74/93, training_loss = 0.0540
# epoch 3/4, step 75/93, training_loss = 0.0274
# epoch 3/4, step 76/93, training_loss = 0.0406
# epoch 3/4, step 77/93, training_loss = 0.0436
# epoch 3/4, step 78/93, training_loss = 0.0485
# epoch 3/4, step 79/93, training_loss = 0.0436
# epoch 3/4, step 80/93, training_loss = 0.0367
# epoch 3/4, step 81/93, training_loss = 0.0416
# epoch 3/4, step 82/93, training_loss = 0.0253
# epoch 3/4, step 83/93, training_loss = 0.0458
# epoch 3/4, step 84/93, training_loss = 0.0421
# epoch 3/4, step 85/93, training_loss = 0.0406
# epoch 3/4, step 86/93, training_loss = 0.0447
# epoch 3/4, step 87/93, training_loss = 0.0383
# epoch 3/4, step 88/93, training_loss = 0.0644
# epoch 3/4, step 89/93, training_loss = 0.0554
# epoch 3/4, step 90/93, training_loss = 0.0455
# epoch 3/4, step 91/93, training_loss = 0.0455
# epoch 3/4, step 92/93, training_loss = 0.0311
# epoch 3/4, step 93/93, training_loss = 0.0733
# evaluation for epoch 3, accuracy = 0.9964, rocauc = 1.0000
# epoch 4/4, step 1/93, training_loss = 0.0321
# epoch 4/4, step 2/93, training_loss = 0.0396
# epoch 4/4, step 3/93, training_loss = 0.0356
# epoch 4/4, step 4/93, training_loss = 0.0250
# epoch 4/4, step 5/93, training_loss = 0.0400
# epoch 4/4, step 6/93, training_loss = 0.0517
# epoch 4/4, step 7/93, training_loss = 0.0419
# epoch 4/4, step 8/93, training_loss = 0.0432
# epoch 4/4, step 9/93, training_loss = 0.0336
# epoch 4/4, step 10/93, training_loss = 0.0412
# epoch 4/4, step 11/93, training_loss = 0.0541
# epoch 4/4, step 12/93, training_loss = 0.0434
# epoch 4/4, step 13/93, training_loss = 0.0473
# epoch 4/4, step 14/93, training_loss = 0.0408
# epoch 4/4, step 15/93, training_loss = 0.0433
# epoch 4/4, step 16/93, training_loss = 0.0288
# epoch 4/4, step 17/93, training_loss = 0.0349
# epoch 4/4, step 18/93, training_loss = 0.0267
# epoch 4/4, step 19/93, training_loss = 0.0413
# epoch 4/4, step 20/93, training_loss = 0.0381
# epoch 4/4, step 21/93, training_loss = 0.0315
# epoch 4/4, step 22/93, training_loss = 0.0301
# epoch 4/4, step 23/93, training_loss = 0.0394
# epoch 4/4, step 24/93, training_loss = 0.0299
# epoch 4/4, step 25/93, training_loss = 0.0462
# epoch 4/4, step 26/93, training_loss = 0.0351
# epoch 4/4, step 27/93, training_loss = 0.0234
# epoch 4/4, step 28/93, training_loss = 0.0303
# epoch 4/4, step 29/93, training_loss = 0.0310
# epoch 4/4, step 30/93, training_loss = 0.0508
# epoch 4/4, step 31/93, training_loss = 0.0399
# epoch 4/4, step 32/93, training_loss = 0.0316
# epoch 4/4, step 33/93, training_loss = 0.0330
# epoch 4/4, step 34/93, training_loss = 0.0245
# epoch 4/4, step 35/93, training_loss = 0.0408
# epoch 4/4, step 36/93, training_loss = 0.0378
# epoch 4/4, step 37/93, training_loss = 0.0338
# epoch 4/4, step 38/93, training_loss = 0.0299
# epoch 4/4, step 39/93, training_loss = 0.0377
# epoch 4/4, step 40/93, training_loss = 0.0617
# epoch 4/4, step 41/93, training_loss = 0.0272
# epoch 4/4, step 42/93, training_loss = 0.0333
# epoch 4/4, step 43/93, training_loss = 0.0314
# epoch 4/4, step 44/93, training_loss = 0.0294
# epoch 4/4, step 45/93, training_loss = 0.0317
# epoch 4/4, step 46/93, training_loss = 0.0517
# epoch 4/4, step 47/93, training_loss = 0.0360
# epoch 4/4, step 48/93, training_loss = 0.0253
# epoch 4/4, step 49/93, training_loss = 0.0303
# epoch 4/4, step 50/93, training_loss = 0.0307
# epoch 4/4, step 51/93, training_loss = 0.0628
# epoch 4/4, step 52/93, training_loss = 0.0331
# epoch 4/4, step 53/93, training_loss = 0.0403
# epoch 4/4, step 54/93, training_loss = 0.0450
# epoch 4/4, step 55/93, training_loss = 0.0225
# epoch 4/4, step 56/93, training_loss = 0.0313
# epoch 4/4, step 57/93, training_loss = 0.0261
# epoch 4/4, step 58/93, training_loss = 0.0323
# epoch 4/4, step 59/93, training_loss = 0.0272
# epoch 4/4, step 60/93, training_loss = 0.0342
# epoch 4/4, step 61/93, training_loss = 0.0358
# epoch 4/4, step 62/93, training_loss = 0.0228
# epoch 4/4, step 63/93, training_loss = 0.0271
# epoch 4/4, step 64/93, training_loss = 0.0310
# epoch 4/4, step 65/93, training_loss = 0.0371
# epoch 4/4, step 66/93, training_loss = 0.0362
# epoch 4/4, step 67/93, training_loss = 0.0276
# epoch 4/4, step 68/93, training_loss = 0.0287
# epoch 4/4, step 69/93, training_loss = 0.0378
# epoch 4/4, step 70/93, training_loss = 0.0277
# epoch 4/4, step 71/93, training_loss = 0.0271
# epoch 4/4, step 72/93, training_loss = 0.0429
# epoch 4/4, step 73/93, training_loss = 0.0417
# epoch 4/4, step 74/93, training_loss = 0.0417
# epoch 4/4, step 75/93, training_loss = 0.0383
# epoch 4/4, step 76/93, training_loss = 0.0380
# epoch 4/4, step 77/93, training_loss = 0.0412
# epoch 4/4, step 78/93, training_loss = 0.0370
# epoch 4/4, step 79/93, training_loss = 0.0253
# epoch 4/4, step 80/93, training_loss = 0.0377
# epoch 4/4, step 81/93, training_loss = 0.0417
# epoch 4/4, step 82/93, training_loss = 0.0487
# epoch 4/4, step 83/93, training_loss = 0.0352
# epoch 4/4, step 84/93, training_loss = 0.0532
# epoch 4/4, step 85/93, training_loss = 0.0306
# epoch 4/4, step 86/93, training_loss = 0.0458
# epoch 4/4, step 87/93, training_loss = 0.0217
# epoch 4/4, step 88/93, training_loss = 0.0522
# epoch 4/4, step 89/93, training_loss = 0.0270
# epoch 4/4, step 90/93, training_loss = 0.0626
# epoch 4/4, step 91/93, training_loss = 0.0231
# epoch 4/4, step 92/93, training_loss = 0.0208
# epoch 4/4, step 93/93, training_loss = 0.0209
# evaluation for epoch 4, accuracy = 0.9971, rocauc = 1.0000
# train completed, best_metric: 1.0000 at epoch: 3

# %% [markdown]
# This demonstrates using Ignite directly with MONAI. The Engine class used here is also extended by MONAI to provide further facilities related to determinism, providing a default training/evaluating iteration implementation, and dealing with the post-processing of data. These types are not necessary so those new to Ignite or already have their own Ignite-based code can integrate MONAI without having to pick up our types.
#
# Using our MONAI classes we can define a simplified version (with a few features omitted):

# %%
from ignite.engine import Events
from ignite.handlers import ModelCheckpoint
from ignite.metrics import Accuracy
from monai.handlers import ROCAUC, ValidationHandler
from monai.engines import SupervisedTrainer, SupervisedEvaluator

train_epochs = 4
iter_losses = []
batch_sizes = []
epoch_loss_values = []
metric_values = []

steps_per_epoch = len(train_ds) // train_loader.batch_size
if len(train_ds) % train_loader.batch_size != 0:
    steps_per_epoch += 1


def roc_auc_trans(x):
    if isinstance(x, list):
        pred = torch.cat([i[0][None, :] for i in x])
        label = torch.cat([i[1][None, :] for i in x])
        return pred, label

    return act(x["pred"]), to_onehot(x["label"])


def prepare_batch(batchdata, device, non_blocking):
    img, classes = batchdata
    return img.to(device), classes.to(device)


evaluator = SupervisedEvaluator(
    device=device,
    val_data_loader=val_loader,
    network=net,
    postprocessing=roc_auc_trans,
    key_val_metric={"rocauc": ROCAUC(output_transform=roc_auc_trans)},
    prepare_batch=prepare_batch,
)

trainer = SupervisedTrainer(
    device=device,
    max_epochs=train_epochs,
    train_data_loader=train_loader,
    network=net,
    optimizer=optimizer,
    loss_function=loss_function,
    train_handlers=[ValidationHandler(1, evaluator)],
    prepare_batch=prepare_batch,
)


@trainer.on(Events.ITERATION_COMPLETED)
def _end_iter(engine):
    loss = np.average([o["loss"] for o in engine.state.output])
    batch_len = len(engine.state.batch[0])
    epoch = engine.state.epoch
    epoch_len = engine.state.max_epochs
    step = engine.state.iteration + 1
    iter_losses.append(loss)
    batch_sizes.append(batch_len)

    print(f"epoch {epoch}/{epoch_len}, step {step}/{steps_per_epoch}, training_loss = {loss:.4f}")


@trainer.on(Events.EPOCH_COMPLETED)
def run_validation(engine):
    # the overall average loss must be weighted by batch size
    overall_average_loss = np.average(iter_losses, weights=batch_sizes)
    epoch_loss_values.append(overall_average_loss)

    # clear the contents of iter_losses and batch_sizes for the next epoch
    del iter_losses[:]
    del batch_sizes[:]

    # fetch and report the validation metrics
    roc = evaluator.state.metrics["rocauc"]
    metric_values.append(roc)
    print(f"evaluation for epoch {engine.state.epoch},  rocauc = {roc:.4f}")


trainer.run()
# Out:
# epoch 1/4, step 2/93, training_loss = 0.0332
# epoch 1/4, step 3/93, training_loss = 0.0423
# epoch 1/4, step 4/93, training_loss = 0.0345
# epoch 1/4, step 5/93, training_loss = 0.0259
# epoch 1/4, step 6/93, training_loss = 0.0384
# epoch 1/4, step 7/93, training_loss = 0.0341
# epoch 1/4, step 8/93, training_loss = 0.0452
# epoch 1/4, step 9/93, training_loss = 0.0434
# epoch 1/4, step 10/93, training_loss = 0.0262
# epoch 1/4, step 11/93, training_loss = 0.0334
# epoch 1/4, step 12/93, training_loss = 0.0426
# epoch 1/4, step 13/93, training_loss = 0.0388
# epoch 1/4, step 14/93, training_loss = 0.0242
# epoch 1/4, step 15/93, training_loss = 0.0267
# epoch 1/4, step 16/93, training_loss = 0.0362
# epoch 1/4, step 17/93, training_loss = 0.0389
# epoch 1/4, step 18/93, training_loss = 0.0338
# epoch 1/4, step 19/93, training_loss = 0.0332
# epoch 1/4, step 20/93, training_loss = 0.0505
# epoch 1/4, step 21/93, training_loss = 0.0290
# epoch 1/4, step 22/93, training_loss = 0.0297
# epoch 1/4, step 23/93, training_loss = 0.0534
# epoch 1/4, step 24/93, training_loss = 0.0195
# epoch 1/4, step 25/93, training_loss = 0.0336
# epoch 1/4, step 26/93, training_loss = 0.0362
# epoch 1/4, step 27/93, training_loss = 0.0339
# epoch 1/4, step 28/93, training_loss = 0.0207
# epoch 1/4, step 29/93, training_loss = 0.0289
# epoch 1/4, step 30/93, training_loss = 0.0403
# epoch 1/4, step 31/93, training_loss = 0.0271
# epoch 1/4, step 32/93, training_loss = 0.0307
# epoch 1/4, step 33/93, training_loss = 0.0376
# epoch 1/4, step 34/93, training_loss = 0.0264
# epoch 1/4, step 35/93, training_loss = 0.0283
# epoch 1/4, step 36/93, training_loss = 0.0262
# epoch 1/4, step 37/93, training_loss = 0.0205
# epoch 1/4, step 38/93, training_loss = 0.0369
# epoch 1/4, step 39/93, training_loss = 0.0209
# epoch 1/4, step 40/93, training_loss = 0.0218
# epoch 1/4, step 41/93, training_loss = 0.0250
# epoch 1/4, step 42/93, training_loss = 0.0443
# epoch 1/4, step 43/93, training_loss = 0.0270
# epoch 1/4, step 44/93, training_loss = 0.0218
# epoch 1/4, step 45/93, training_loss = 0.0287
# epoch 1/4, step 46/93, training_loss = 0.0429
# epoch 1/4, step 47/93, training_loss = 0.0297
# epoch 1/4, step 48/93, training_loss = 0.0230
# epoch 1/4, step 49/93, training_loss = 0.0318
# epoch 1/4, step 50/93, training_loss = 0.0236
# epoch 1/4, step 51/93, training_loss = 0.0286
# epoch 1/4, step 52/93, training_loss = 0.0242
# epoch 1/4, step 53/93, training_loss = 0.0215
# epoch 1/4, step 54/93, training_loss = 0.0367
# epoch 1/4, step 55/93, training_loss = 0.0363
# epoch 1/4, step 56/93, training_loss = 0.0225
# epoch 1/4, step 57/93, training_loss = 0.0314
# epoch 1/4, step 58/93, training_loss = 0.0314
# epoch 1/4, step 59/93, training_loss = 0.0225
# epoch 1/4, step 60/93, training_loss = 0.0438
# epoch 1/4, step 61/93, training_loss = 0.0228
# epoch 1/4, step 62/93, training_loss = 0.0320
# epoch 1/4, step 63/93, training_loss = 0.0324
# epoch 1/4, step 64/93, training_loss = 0.0448
# epoch 1/4, step 65/93, training_loss = 0.0423
# epoch 1/4, step 66/93, training_loss = 0.0271
# epoch 1/4, step 67/93, training_loss = 0.0281
# epoch 1/4, step 68/93, training_loss = 0.0272
# epoch 1/4, step 69/93, training_loss = 0.0231
# epoch 1/4, step 70/93, training_loss = 0.0317
# epoch 1/4, step 71/93, training_loss = 0.0423
# epoch 1/4, step 72/93, training_loss = 0.0283
# epoch 1/4, step 73/93, training_loss = 0.0282
# epoch 1/4, step 74/93, training_loss = 0.0388
# epoch 1/4, step 75/93, training_loss = 0.0255
# epoch 1/4, step 76/93, training_loss = 0.0350
# epoch 1/4, step 77/93, training_loss = 0.0283
# epoch 1/4, step 78/93, training_loss = 0.0380
# epoch 1/4, step 79/93, training_loss = 0.0260
# epoch 1/4, step 80/93, training_loss = 0.0172
# epoch 1/4, step 81/93, training_loss = 0.0278
# epoch 1/4, step 82/93, training_loss = 0.0522
# epoch 1/4, step 83/93, training_loss = 0.0482
# epoch 1/4, step 84/93, training_loss = 0.0298
# epoch 1/4, step 85/93, training_loss = 0.0217
# epoch 1/4, step 86/93, training_loss = 0.0289
# epoch 1/4, step 87/93, training_loss = 0.0255
# epoch 1/4, step 88/93, training_loss = 0.0264
# epoch 1/4, step 89/93, training_loss = 0.0232
# epoch 1/4, step 90/93, training_loss = 0.0212
# epoch 1/4, step 91/93, training_loss = 0.0217
# epoch 1/4, step 92/93, training_loss = 0.0222
# epoch 1/4, step 93/93, training_loss = 0.0307
# epoch 1/4, step 94/93, training_loss = 0.0209
# evaluation for epoch 1,  rocauc = 1.0000
# epoch 2/4, step 95/93, training_loss = 0.0419
# epoch 2/4, step 96/93, training_loss = 0.0343
# epoch 2/4, step 97/93, training_loss = 0.0196
# epoch 2/4, step 98/93, training_loss = 0.0294
# epoch 2/4, step 99/93, training_loss = 0.0229
# epoch 2/4, step 100/93, training_loss = 0.0351
# epoch 2/4, step 101/93, training_loss = 0.0190
# epoch 2/4, step 102/93, training_loss = 0.0318
# epoch 2/4, step 103/93, training_loss = 0.0255
# epoch 2/4, step 104/93, training_loss = 0.0210
# epoch 2/4, step 105/93, training_loss = 0.0208
# epoch 2/4, step 106/93, training_loss = 0.0208
# epoch 2/4, step 107/93, training_loss = 0.0261
# epoch 2/4, step 108/93, training_loss = 0.0335
# epoch 2/4, step 109/93, training_loss = 0.0334
# epoch 2/4, step 110/93, training_loss = 0.0324
# epoch 2/4, step 111/93, training_loss = 0.0271
# epoch 2/4, step 112/93, training_loss = 0.0214
# epoch 2/4, step 113/93, training_loss = 0.0200
# epoch 2/4, step 114/93, training_loss = 0.0283
# epoch 2/4, step 115/93, training_loss = 0.0233
# epoch 2/4, step 116/93, training_loss = 0.0306
# epoch 2/4, step 117/93, training_loss = 0.0271
# epoch 2/4, step 118/93, training_loss = 0.0285
# epoch 2/4, step 119/93, training_loss = 0.0167
# epoch 2/4, step 120/93, training_loss = 0.0323
# epoch 2/4, step 121/93, training_loss = 0.0183
# epoch 2/4, step 122/93, training_loss = 0.0264
# epoch 2/4, step 123/93, training_loss = 0.0288
# epoch 2/4, step 124/93, training_loss = 0.0257
# epoch 2/4, step 125/93, training_loss = 0.0184
# epoch 2/4, step 126/93, training_loss = 0.0190
# epoch 2/4, step 127/93, training_loss = 0.0293
# epoch 2/4, step 128/93, training_loss = 0.0224
# epoch 2/4, step 129/93, training_loss = 0.0157
# epoch 2/4, step 130/93, training_loss = 0.0331
# epoch 2/4, step 131/93, training_loss = 0.0192
# epoch 2/4, step 132/93, training_loss = 0.0389
# epoch 2/4, step 133/93, training_loss = 0.0278
# epoch 2/4, step 134/93, training_loss = 0.0186
# epoch 2/4, step 135/93, training_loss = 0.0281
# epoch 2/4, step 136/93, training_loss = 0.0341
# epoch 2/4, step 137/93, training_loss = 0.0292
# epoch 2/4, step 138/93, training_loss = 0.0401
# epoch 2/4, step 139/93, training_loss = 0.0192
# epoch 2/4, step 140/93, training_loss = 0.0360
# epoch 2/4, step 141/93, training_loss = 0.0197
# epoch 2/4, step 142/93, training_loss = 0.0243
# epoch 2/4, step 143/93, training_loss = 0.0224
# epoch 2/4, step 144/93, training_loss = 0.0338
# epoch 2/4, step 145/93, training_loss = 0.0266
# epoch 2/4, step 146/93, training_loss = 0.0268
# epoch 2/4, step 147/93, training_loss = 0.0266
# epoch 2/4, step 148/93, training_loss = 0.0268
# epoch 2/4, step 149/93, training_loss = 0.0252
# epoch 2/4, step 150/93, training_loss = 0.0287
# epoch 2/4, step 151/93, training_loss = 0.0366
# epoch 2/4, step 152/93, training_loss = 0.0220
# epoch 2/4, step 153/93, training_loss = 0.0253
# epoch 2/4, step 154/93, training_loss = 0.0249
# epoch 2/4, step 155/93, training_loss = 0.0208
# epoch 2/4, step 156/93, training_loss = 0.0200
# epoch 2/4, step 157/93, training_loss = 0.0234
# epoch 2/4, step 158/93, training_loss = 0.0361
# epoch 2/4, step 159/93, training_loss = 0.0195
# epoch 2/4, step 160/93, training_loss = 0.0250
# epoch 2/4, step 161/93, training_loss = 0.0263
# epoch 2/4, step 162/93, training_loss = 0.0153
# epoch 2/4, step 163/93, training_loss = 0.0350
# epoch 2/4, step 164/93, training_loss = 0.0210
# epoch 2/4, step 165/93, training_loss = 0.0213
# epoch 2/4, step 166/93, training_loss = 0.0286
# epoch 2/4, step 167/93, training_loss = 0.0338
# epoch 2/4, step 168/93, training_loss = 0.0283
# epoch 2/4, step 169/93, training_loss = 0.0168
# epoch 2/4, step 170/93, training_loss = 0.0218
# epoch 2/4, step 171/93, training_loss = 0.0161
# epoch 2/4, step 172/93, training_loss = 0.0337
# epoch 2/4, step 173/93, training_loss = 0.0121
# epoch 2/4, step 174/93, training_loss = 0.0409
# epoch 2/4, step 175/93, training_loss = 0.0205
# epoch 2/4, step 176/93, training_loss = 0.0207
# epoch 2/4, step 177/93, training_loss = 0.0269
# epoch 2/4, step 178/93, training_loss = 0.0403
# epoch 2/4, step 179/93, training_loss = 0.0151
# epoch 2/4, step 180/93, training_loss = 0.0245
# epoch 2/4, step 181/93, training_loss = 0.0203
# epoch 2/4, step 182/93, training_loss = 0.0270
# epoch 2/4, step 183/93, training_loss = 0.0207
# epoch 2/4, step 184/93, training_loss = 0.0147
# epoch 2/4, step 185/93, training_loss = 0.0221
# epoch 2/4, step 186/93, training_loss = 0.0236
# epoch 2/4, step 187/93, training_loss = 0.0450
# evaluation for epoch 2,  rocauc = 1.0000
# epoch 3/4, step 188/93, training_loss = 0.0446
# epoch 3/4, step 189/93, training_loss = 0.0289
# epoch 3/4, step 190/93, training_loss = 0.0304
# epoch 3/4, step 191/93, training_loss = 0.0248
# epoch 3/4, step 192/93, training_loss = 0.0242
# epoch 3/4, step 193/93, training_loss = 0.0325
# epoch 3/4, step 194/93, training_loss = 0.0260
# epoch 3/4, step 195/93, training_loss = 0.0200
# epoch 3/4, step 196/93, training_loss = 0.0170
# epoch 3/4, step 197/93, training_loss = 0.0281
# epoch 3/4, step 198/93, training_loss = 0.0282
# epoch 3/4, step 199/93, training_loss = 0.0180
# epoch 3/4, step 200/93, training_loss = 0.0381
# epoch 3/4, step 201/93, training_loss = 0.0233
# epoch 3/4, step 202/93, training_loss = 0.0117
# epoch 3/4, step 203/93, training_loss = 0.0215
# epoch 3/4, step 204/93, training_loss = 0.0207
# epoch 3/4, step 205/93, training_loss = 0.0267
# epoch 3/4, step 206/93, training_loss = 0.0162
# epoch 3/4, step 207/93, training_loss = 0.0128
# epoch 3/4, step 208/93, training_loss = 0.0228
# epoch 3/4, step 209/93, training_loss = 0.0196
# epoch 3/4, step 210/93, training_loss = 0.0210
# epoch 3/4, step 211/93, training_loss = 0.0148
# epoch 3/4, step 212/93, training_loss = 0.0230
# epoch 3/4, step 213/93, training_loss = 0.0232
# epoch 3/4, step 214/93, training_loss = 0.0245
# epoch 3/4, step 215/93, training_loss = 0.0288
# epoch 3/4, step 216/93, training_loss = 0.0404
# epoch 3/4, step 217/93, training_loss = 0.0236
# epoch 3/4, step 218/93, training_loss = 0.0150
# epoch 3/4, step 219/93, training_loss = 0.0245
# epoch 3/4, step 220/93, training_loss = 0.0159
# epoch 3/4, step 221/93, training_loss = 0.0265
# epoch 3/4, step 222/93, training_loss = 0.0158
# epoch 3/4, step 223/93, training_loss = 0.0177
# epoch 3/4, step 224/93, training_loss = 0.0294
# epoch 3/4, step 225/93, training_loss = 0.0256
# epoch 3/4, step 226/93, training_loss = 0.0132
# epoch 3/4, step 227/93, training_loss = 0.0180
# epoch 3/4, step 228/93, training_loss = 0.0160
# epoch 3/4, step 229/93, training_loss = 0.0329
# epoch 3/4, step 230/93, training_loss = 0.0386
# epoch 3/4, step 231/93, training_loss = 0.0337
# epoch 3/4, step 232/93, training_loss = 0.0258
# epoch 3/4, step 233/93, training_loss = 0.0277
# epoch 3/4, step 234/93, training_loss = 0.0434
# epoch 3/4, step 235/93, training_loss = 0.0160
# epoch 3/4, step 236/93, training_loss = 0.0151
# epoch 3/4, step 237/93, training_loss = 0.0202
# epoch 3/4, step 238/93, training_loss = 0.0253
# epoch 3/4, step 239/93, training_loss = 0.0249
# epoch 3/4, step 240/93, training_loss = 0.0100
# epoch 3/4, step 241/93, training_loss = 0.0165
# epoch 3/4, step 242/93, training_loss = 0.0134
# epoch 3/4, step 243/93, training_loss = 0.0227
# epoch 3/4, step 244/93, training_loss = 0.0140
# epoch 3/4, step 245/93, training_loss = 0.0180
# epoch 3/4, step 246/93, training_loss = 0.0148
# epoch 3/4, step 247/93, training_loss = 0.0153
# epoch 3/4, step 248/93, training_loss = 0.0239
# epoch 3/4, step 249/93, training_loss = 0.0174
# epoch 3/4, step 250/93, training_loss = 0.0138
# epoch 3/4, step 251/93, training_loss = 0.0124
# epoch 3/4, step 252/93, training_loss = 0.0143
# epoch 3/4, step 253/93, training_loss = 0.0135
# epoch 3/4, step 254/93, training_loss = 0.0260
# epoch 3/4, step 255/93, training_loss = 0.0211
# epoch 3/4, step 256/93, training_loss = 0.0372
# epoch 3/4, step 257/93, training_loss = 0.0313
# epoch 3/4, step 258/93, training_loss = 0.0230
# epoch 3/4, step 259/93, training_loss = 0.0204
# epoch 3/4, step 260/93, training_loss = 0.0121
# epoch 3/4, step 261/93, training_loss = 0.0107
# epoch 3/4, step 262/93, training_loss = 0.0251
# epoch 3/4, step 263/93, training_loss = 0.0190
# epoch 3/4, step 264/93, training_loss = 0.0227
# epoch 3/4, step 265/93, training_loss = 0.0221
# epoch 3/4, step 266/93, training_loss = 0.0283
# epoch 3/4, step 267/93, training_loss = 0.0095
# epoch 3/4, step 268/93, training_loss = 0.0200
# epoch 3/4, step 269/93, training_loss = 0.0300
# epoch 3/4, step 270/93, training_loss = 0.0208
# epoch 3/4, step 271/93, training_loss = 0.0279
# epoch 3/4, step 272/93, training_loss = 0.0197
# epoch 3/4, step 273/93, training_loss = 0.0182
# epoch 3/4, step 274/93, training_loss = 0.0188
# epoch 3/4, step 275/93, training_loss = 0.0228
# epoch 3/4, step 276/93, training_loss = 0.0113
# epoch 3/4, step 277/93, training_loss = 0.0134
# epoch 3/4, step 278/93, training_loss = 0.0154
# epoch 3/4, step 279/93, training_loss = 0.0098
# epoch 3/4, step 280/93, training_loss = 0.0357
# evaluation for epoch 3,  rocauc = 1.0000
# epoch 4/4, step 281/93, training_loss = 0.0184
# epoch 4/4, step 282/93, training_loss = 0.0322
# epoch 4/4, step 283/93, training_loss = 0.0231
# epoch 4/4, step 284/93, training_loss = 0.0375
# epoch 4/4, step 285/93, training_loss = 0.0169
# epoch 4/4, step 286/93, training_loss = 0.0150
# epoch 4/4, step 287/93, training_loss = 0.0174
# epoch 4/4, step 288/93, training_loss = 0.0323
# epoch 4/4, step 289/93, training_loss = 0.0105
# epoch 4/4, step 290/93, training_loss = 0.0248
# epoch 4/4, step 291/93, training_loss = 0.0106
# epoch 4/4, step 292/93, training_loss = 0.0168
# epoch 4/4, step 293/93, training_loss = 0.0234
# epoch 4/4, step 294/93, training_loss = 0.0158
# epoch 4/4, step 295/93, training_loss = 0.0172
# epoch 4/4, step 296/93, training_loss = 0.0140
# epoch 4/4, step 297/93, training_loss = 0.0160
# epoch 4/4, step 298/93, training_loss = 0.0173
# epoch 4/4, step 299/93, training_loss = 0.0297
# epoch 4/4, step 300/93, training_loss = 0.0213
# epoch 4/4, step 301/93, training_loss = 0.0183
# epoch 4/4, step 302/93, training_loss = 0.0151
# epoch 4/4, step 303/93, training_loss = 0.0229
# epoch 4/4, step 304/93, training_loss = 0.0209
# epoch 4/4, step 305/93, training_loss = 0.0134
# epoch 4/4, step 306/93, training_loss = 0.0189
# epoch 4/4, step 307/93, training_loss = 0.0199
# epoch 4/4, step 308/93, training_loss = 0.0118
# epoch 4/4, step 309/93, training_loss = 0.0094
# epoch 4/4, step 310/93, training_loss = 0.0157
# epoch 4/4, step 311/93, training_loss = 0.0092
# epoch 4/4, step 312/93, training_loss = 0.0193
# epoch 4/4, step 313/93, training_loss = 0.0233
# epoch 4/4, step 314/93, training_loss = 0.0108
# epoch 4/4, step 315/93, training_loss = 0.0171
# epoch 4/4, step 316/93, training_loss = 0.0143
# epoch 4/4, step 317/93, training_loss = 0.0114
# epoch 4/4, step 318/93, training_loss = 0.0149
# epoch 4/4, step 319/93, training_loss = 0.0120
# epoch 4/4, step 320/93, training_loss = 0.0132
# epoch 4/4, step 321/93, training_loss = 0.0132
# epoch 4/4, step 322/93, training_loss = 0.0267
# epoch 4/4, step 323/93, training_loss = 0.0119
# epoch 4/4, step 324/93, training_loss = 0.0130
# epoch 4/4, step 325/93, training_loss = 0.0212
# epoch 4/4, step 326/93, training_loss = 0.0113
# epoch 4/4, step 327/93, training_loss = 0.0382
# epoch 4/4, step 328/93, training_loss = 0.0166
# epoch 4/4, step 329/93, training_loss = 0.0110
# epoch 4/4, step 330/93, training_loss = 0.0213
# epoch 4/4, step 331/93, training_loss = 0.0219
# epoch 4/4, step 332/93, training_loss = 0.0315
# epoch 4/4, step 333/93, training_loss = 0.0136
# epoch 4/4, step 334/93, training_loss = 0.0117
# epoch 4/4, step 335/93, training_loss = 0.0208
# epoch 4/4, step 336/93, training_loss = 0.0107
# epoch 4/4, step 337/93, training_loss = 0.0213
# epoch 4/4, step 338/93, training_loss = 0.0200
# epoch 4/4, step 339/93, training_loss = 0.0184
# epoch 4/4, step 340/93, training_loss = 0.0186
# epoch 4/4, step 341/93, training_loss = 0.0259
# epoch 4/4, step 342/93, training_loss = 0.0228
# epoch 4/4, step 343/93, training_loss = 0.0113
# epoch 4/4, step 344/93, training_loss = 0.0162
# epoch 4/4, step 345/93, training_loss = 0.0254
# epoch 4/4, step 346/93, training_loss = 0.0185
# epoch 4/4, step 347/93, training_loss = 0.0119
# epoch 4/4, step 348/93, training_loss = 0.0208
# epoch 4/4, step 349/93, training_loss = 0.0453
# epoch 4/4, step 350/93, training_loss = 0.0133
# epoch 4/4, step 351/93, training_loss = 0.0203
# epoch 4/4, step 352/93, training_loss = 0.0201
# epoch 4/4, step 353/93, training_loss = 0.0311
# epoch 4/4, step 354/93, training_loss = 0.0095
# epoch 4/4, step 355/93, training_loss = 0.0140
# epoch 4/4, step 356/93, training_loss = 0.0142
# epoch 4/4, step 357/93, training_loss = 0.0156
# epoch 4/4, step 358/93, training_loss = 0.0159
# epoch 4/4, step 359/93, training_loss = 0.0113
# epoch 4/4, step 360/93, training_loss = 0.0260
# epoch 4/4, step 361/93, training_loss = 0.0180
# epoch 4/4, step 362/93, training_loss = 0.0103
# epoch 4/4, step 363/93, training_loss = 0.0280
# epoch 4/4, step 364/93, training_loss = 0.0139
# epoch 4/4, step 365/93, training_loss = 0.0195
# epoch 4/4, step 366/93, training_loss = 0.0167
# epoch 4/4, step 367/93, training_loss = 0.0187
# epoch 4/4, step 368/93, training_loss = 0.0242
# epoch 4/4, step 369/93, training_loss = 0.0140
# epoch 4/4, step 370/93, training_loss = 0.0147
# epoch 4/4, step 371/93, training_loss = 0.0154
# epoch 4/4, step 372/93, training_loss = 0.0187
# epoch 4/4, step 373/93, training_loss = 0.0122
# evaluation for epoch 4,  rocauc = 1.0000

# %% [markdown]
# ## Issues with determinism
#
# MONAI provides `monai.utils.set_determinism` for replicable training
# - Easy to not think about, especially in a jupyter / IPython notebook
#
# How many uses of `numpy.random`'s underlying global instance does this notebook have?
# - Dataset partitioning
# - Image previewing
# - MONAI transforms with randomised behaviour can be given / told to create their own internal `numpy.random.RandomState` instances

# %% [markdown]
# #### Setting up transforms, revisited

# %%
rseed = 12345678

train_transforms = Compose(
    [
        LoadImage(image_only=True),
        AddChannel(),
        ScaleIntensity(),
        RandRotate(range_x=15, prob=0.5, keep_size=True).set_random_state(rseed),
        RandFlip(spatial_axis=0, prob=0.5).set_random_state(rseed),
        RandZoom(min_zoom=0.9, max_zoom=1.1, prob=0.5).set_random_state(rseed),
        ToTensor(),
    ]
)

val_transforms = Compose([LoadImage(image_only=True), AddChannel(), ScaleIntensity(), ToTensor()])

# %% [markdown]
# #### Improving dataset partitioning
#
# Current code results in random numbers of images / labels each time it is run in each category. The solution is to use a deterministic shuffle:

# %%
parts = partition_dataset_classes(
    data=np.arange(len(image_files_list)), 
    classes=image_class, 
    ratios=(8, 1, 1), 
    shuffle=True, 
    seed=rseed
)

image_sets = [list(), list(), list()]
label_sets = [list(), list(), list()]

for i, part in enumerate(parts):
    image_sets[i] = [image_files_list[idx] for idx in part]
    label_sets[i] = [image_class[idx] for idx in part]

train_x, val_x, test_x = image_sets
train_y, val_y, test_y = label_sets
print(len(train_x), len(val_x), len(test_x))
# Out:
# 47163 5895 5895

# %% [markdown]
# ## **Summary**
#
# In this notebook, we went through an end-to-end workflow to train the MedNIST dataset using a densenet121 network.  Along the way, you did the following:
# - Learned about the MedNIST Data and downloaded it
# - Visualized the data to understand the images
# - Setup the datasets for use in the model training
# - Defined our transforms, datasets, network, and optimizers
# - Trained a densenet model and saved the best model as determined by the validation accuracy
# - Plotted your training results
# - Evaluated your model against the test set
# - Ran your final predictions through a classification report to understand more about your final results
# - Created a new workflow using Ignite
# - Learn more about issues with determinism and how to look out for pitfalls

# %% [markdown]
# ## **Next Steps**
#
# On day 3 we'll be giving you the opportunity to put all of this together in a single task. We'll have a number of challenges to choose from but you'll need all of your MONAI know how no matter which one you choose.
#
# You can find more information about everything covered here on our [MONAI Documentation Page](https://docs.monai.io/).
#
# If you're looking for more examples and tutorials, we have a repo dedicated just to that!  You can find it on our [GitHub Organization Page](https://github.com/Project-MONAI/tutorials).  We also have all of our videos from our first ever MONAI Bootcamp available on our [Youtube Channel](https://www.youtube.com/c/ProjectMONAI)
